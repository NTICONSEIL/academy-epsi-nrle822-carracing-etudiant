# %% [markdown]
# # 🏎️ Phase 2 — Apprentissage supervisé : imitation d'un pilote
# ## NRLE822 · Version Apprenant
#
# > 🔧 Complétez les cellules marquées `# TODO`
#
# **Objectifs :** Charger les CSV d'épisodes et afficher les statistiques des actions | Implémenter le split train/val/test PAR ÉPISODE (pas par ligne) | Créer la classe DrivingDataset héritant de torch.utils.data.Dataset

# %%
import numpy as np, pandas as pd, sys, os
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import gymnasium as gym
sys.path.append('..')
from utils.env_wrappers import make_env
from utils.metrics import *

SEED = 42
np.random.seed(SEED); torch.manual_seed(SEED)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# %% [markdown]
# ## Exercice 1
# Charger les CSV d'épisodes et afficher les statistiques des actions

# %%
# TODO 1 : Charger les CSV d'épisodes et afficher les statistiques des actions

# Votre code ici

# %% [markdown]
# ## Exercice 2
# Implémenter le split train/val/test PAR ÉPISODE (pas par ligne)

# %%
# TODO 2 : Implémenter le split train/val/test PAR ÉPISODE (pas par ligne)

# Votre code ici

# %% [markdown]
# ## Exercice 3
# Créer la classe DrivingDataset héritant de torch.utils.data.Dataset

# %%
# TODO 3 : Créer la classe DrivingDataset héritant de torch.utils.data.Dataset

# Votre code ici

# %% [markdown]
# ## Exercice 4
# Implémenter la boucle d'entraînement avec MSELoss et Adam

# %%
# TODO 4 : Implémenter la boucle d'entraînement avec MSELoss et Adam

# Votre code ici

# %% [markdown]
# ## Exercice 5
# Calculer RMSE, MAE et précision directionnelle sur le test set

# %%
# TODO 5 : Calculer RMSE, MAE et précision directionnelle sur le test set

# Votre code ici

# %% [markdown]
# ## Exercice 6
# Comparer avec une baseline naïve (prédire la moyenne d'entraînement)

# %%
# TODO 6 : Comparer avec une baseline naïve (prédire la moyenne d'entraînement)

# Votre code ici

# %% [markdown]
# ## Exercice 7
# Tester 3 valeurs de learning rate et comparer les courbes de loss

# %%
# TODO 7 : Tester 3 valeurs de learning rate et comparer les courbes de loss

# Votre code ici
