# %% [markdown]
# # 🏎️ Phase 3 — Mémoire temporelle : RNN / LSTM
# ## NRLE822 · Version Apprenant
#
# > 🔧 Complétez les cellules marquées `# TODO`
#
# **Objectifs :** Visualiser l'auto-corrélation du steering (pd.Series.autocorr) | Implémenter SequenceDataset avec fenêtres glissantes de longueur T | Implémenter LSTMDriver (encodeur linéaire + LSTM + tête de régression)

# %%
import numpy as np, pandas as pd, sys, os
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import gymnasium as gym
sys.path.append('..')
from utils.env_wrappers import make_env
from utils.metrics import *

SEED = 42
np.random.seed(SEED); torch.manual_seed(SEED)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# %% [markdown]
# ## Exercice 1
# Visualiser l'auto-corrélation du steering (pd.Series.autocorr)

# %%
# TODO 1 : Visualiser l'auto-corrélation du steering (pd.Series.autocorr)

# Votre code ici

# %% [markdown]
# ## Exercice 2
# Implémenter SequenceDataset avec fenêtres glissantes de longueur T

# %%
# TODO 2 : Implémenter SequenceDataset avec fenêtres glissantes de longueur T

# Votre code ici

# %% [markdown]
# ## Exercice 3
# Implémenter LSTMDriver (encodeur linéaire + LSTM + tête de régression)

# %%
# TODO 3 : Implémenter LSTMDriver (encodeur linéaire + LSTM + tête de régression)

# Votre code ici

# %% [markdown]
# ## Exercice 4
# Implémenter GRUDriver comme variante simplifiée

# %%
# TODO 4 : Implémenter GRUDriver comme variante simplifiée

# Votre code ici

# %% [markdown]
# ## Exercice 5
# Comparer LSTM vs GRU sur RMSE, MAE et précision directionnelle

# %%
# TODO 5 : Comparer LSTM vs GRU sur RMSE, MAE et précision directionnelle

# Votre code ici

# %% [markdown]
# ## Exercice 6
# Expérimenter avec différentes longueurs de séquence (T=5, 10, 20)

# %%
# TODO 6 : Expérimenter avec différentes longueurs de séquence (T=5, 10, 20)

# Votre code ici
