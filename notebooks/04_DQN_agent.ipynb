# %% [markdown]
# # 🏎️ Phase 4 — Agent autonome : Q-Learning / DQN
# ## NRLE822 · Version Apprenant
#
# > 🔧 Complétez les cellules marquées `# TODO`
#
# **Objectifs :** Créer l'environnement discrétisé avec make_env(discrete=True, grayscale=True, resize=(42,42)) | Implémenter la classe DQN (CNN + tête FC sans activation finale) | Implémenter select_action() avec la stratégie ε-greedy

# %%
import numpy as np, pandas as pd, sys, os
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import gymnasium as gym
sys.path.append('..')
from utils.env_wrappers import make_env
from utils.metrics import *

SEED = 42
np.random.seed(SEED); torch.manual_seed(SEED)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# %% [markdown]
# ## Exercice 1
# Créer l'environnement discrétisé avec make_env(discrete=True, grayscale=True, resize=(42,42))

# %%
# TODO 1 : Créer l'environnement discrétisé avec make_env(discrete=True, grayscale=True, resize=(42,42))

# Votre code ici

# %% [markdown]
# ## Exercice 2
# Implémenter la classe DQN (CNN + tête FC sans activation finale)

# %%
# TODO 2 : Implémenter la classe DQN (CNN + tête FC sans activation finale)

# Votre code ici

# %% [markdown]
# ## Exercice 3
# Implémenter select_action() avec la stratégie ε-greedy

# %%
# TODO 3 : Implémenter select_action() avec la stratégie ε-greedy

# Votre code ici

# %% [markdown]
# ## Exercice 4
# Implémenter train_step() avec l'équation de Bellman

# %%
# TODO 4 : Implémenter train_step() avec l'équation de Bellman

# Votre code ici

# %% [markdown]
# ## Exercice 5
# Coder la boucle d'entraînement (store → train_step → update_epsilon → update_target)

# %%
# TODO 5 : Coder la boucle d'entraînement (store → train_step → update_epsilon → update_target)

# Votre code ici

# %% [markdown]
# ## Exercice 6
# Tracer la courbe de récompense avec moyenne mobile

# %%
# TODO 6 : Tracer la courbe de récompense avec moyenne mobile

# Votre code ici

# %% [markdown]
# ## Exercice 7
# Expérimenter avec γ ∈ {0.90, 0.95, 0.99} et analyser l'impact

# %%
# TODO 7 : Expérimenter avec γ ∈ {0.90, 0.95, 0.99} et analyser l'impact

# Votre code ici
